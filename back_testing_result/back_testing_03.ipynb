# %%
''' 
이번 백테스팅은 noise가 낮은 코인들을 
가격 ma5상승장 + 거래량 ma5 상승장 + 변동성돌파
했을때의 수익률을 보겠다.
'''
# Out:
# ' \n이번 백테스팅은 noise가 낮은 코인들을 \n가격 ma5상승장 + 거래량 ma5 상승장 + 변동성돌파\n했을때의 수익률을 보겠다.\n'

# %%
import pybithumb
import time
import datetime
import pandas as pd
import numpy as np

# %%
# noise data
def noise():
    tickers = pybithumb.get_tickers()
    new_df = pd.DataFrame()
    for ticker in tickers:
        df = pybithumb.get_ohlcv(ticker)
        df = df[df.index > '2017']
        df['noise'] = np.round(1 - (abs(df['open']-df['close']) / (df['high']-df['low'])), 2)
        df['noise_ma20'] = df['noise'].rolling(window=20).mean().shift(1)
        df['noise'] = df['noise'].shift(1)
        df['ticker'] = ticker
        
        df['ma5'] = df['close'].rolling(window=5).mean().shift(1)
        df['bull_ma'] = df['open'] > df['ma5']
        
        df['v_ma5'] = df['volume'].rolling(window=5).mean().shift(1)
        df['bull_vma'] = df['volume'] > df['v_ma5']
        
        new_df = new_df.append(df)
    return new_df

# %%
noise_df = noise()
noise_df
# Out:
#                   open       high         low       close        volume  \
# 2017-01-02  1215000.00  1328000.0  1213000.00  1323000.00  1.024099e+04
# 2017-01-03  1323000.00  1428000.0  1271000.00  1343000.00  1.415321e+04
# 2017-01-04  1347000.00  1420000.0  1342000.00  1404000.00  9.969498e+03
# 2017-01-05  1405000.00  1700000.0  1155000.00  1324000.00  2.355459e+04
# 2017-01-06  1323000.00  1530000.0  1077000.00  1172000.00  2.122767e+04
# 2017-01-07  1173000.00  1243000.0  1002000.00  1115000.00  1.881177e+04
# 2017-01-08  1114000.00  1215000.0  1097000.00  1167000.00  1.169237e+04
# 2017-01-09  1164000.00  1179000.0  1100000.00  1120000.00  1.018561e+04
# 2017-01-10  1120000.00  1140000.0  1105000.00  1113000.00  6.631172e+03
# 2017-01-11  1112000.00  1127000.0   911000.00   997000.00  1.283009e+04
# 2017-01-12   997000.00   997000.0   887000.00   924000.00  1.424646e+04
# 2017-01-13   926000.00   990000.0   911000.00   963000.00  1.211857e+04
# 2017-01-14   964000.00   999000.0   957000.00   988000.00  7.454919e+03
# 2017-01-15   989000.00   997000.0   963000.00   975000.00  4.765694e+03
# 2017-01-16   975000.00   989000.0   965000.00   985000.00  4.897023e+03
# 2017-01-17   985000.00  1118000.0   983000.00  1065000.00  1.226220e+04
# 2017-01-18  1063000.00  1111000.0  1005000.00  1037000.00  1.186071e+04
# 2017-01-19  1038000.00  1076000.0  1031000.00  1065000.00  6.791716e+03
# 2017-01-20  1065000.00  1080000.0  1059000.00  1070000.00  4.625314e+03
# 2017-01-21  1070000.00  1105000.0  1067000.00  1097000.00  5.293152e+03
# 2017-01-22  1095000.00  1121000.0  1066000.00  1094000.00  6.351656e+03
# 2017-01-23  1090000.00  1110000.0  1086000.00  1101000.00  4.091358e+03
# 2017-01-24  1101000.00  1106000.0  1080000.00  1085000.00  5.374938e+03
# 2017-01-25  1086000.00  1092000.0  1071000.00  1077000.00  4.466059e+03
# 2017-01-26  1074000.00  1091000.0  1070000.00  1089000.00  3.687036e+03
# 2017-01-27  1090000.00  1099000.0  1085000.00  1092000.00  3.161633e+03
# 2017-01-28  1093000.00  1099000.0  1091000.00  1096000.00  9.548910e+02
# 2017-01-29  1096000.00  1100000.0  1095000.00  1100000.00  1.071159e+03
# 2017-01-30  1100000.00  1101000.0  1095000.00  1100000.00  1.607075e+03
# 2017-01-31  1100000.00  1145000.0  1090000.00  1132000.00  5.873883e+03
# ...                ...        ...         ...         ...           ...
# 2019-07-18        8.51        9.4        8.50        9.09  5.176589e+07
# 2019-07-19        9.10       10.9        9.01       10.00  1.725173e+08
# 2019-07-20       10.00       10.4        9.75       10.20  6.813799e+07
# 2019-07-21       10.10       10.4        9.14        9.23  1.693756e+08
# 2019-07-22        9.23        9.4        9.13        9.34  6.682864e+06
# 2019-07-04       61.00       79.0       55.30       56.90  9.214137e+08
# 2019-07-05       56.70       57.5       51.10       53.00  9.517778e+08
# 2019-07-06       53.00       53.1       49.20       50.10  9.553889e+08
# 2019-07-07       50.10       53.5       49.80       50.40  1.974391e+07
# 2019-07-08       50.10       51.0       48.30       48.30  9.711062e+06
# 2019-07-09       48.30       49.1       44.60       46.00  9.007219e+06
# 2019-07-10       46.00       53.9       44.60       44.80  3.743353e+07
# 2019-07-11       44.80       47.3       38.50       40.90  1.145928e+07
# 2019-07-12       40.90       42.7       36.40       40.90  7.865084e+06
# 2019-07-13       40.90       43.0       38.30       40.10  1.217391e+07
# 2019-07-14       39.50       40.7       35.20       35.20  7.237608e+06
# 2019-07-15       35.20       35.8       29.60       31.80  1.275981e+07
# 2019-07-16       31.70       32.3       28.50       28.80  9.088537e+06
# 2019-07-17       28.90       29.9       22.60       24.40  2.734136e+07
# 2019-07-18       24.30       27.1       23.00       24.60  2.018666e+07
# 2019-07-19       24.60       26.5       24.60       25.50  1.597022e+07
# 2019-07-20       25.60       27.8       25.20       27.60  1.243048e+07
# 2019-07-21       27.20       28.3       26.20       26.30  4.353496e+06
# 2019-07-22       26.40       26.5       26.30       26.30  5.308767e+04
# 2019-07-17      265.00      284.0      230.00      243.00  1.903053e+08
# 2019-07-18      243.00      257.0      234.00      246.00  1.807655e+08
# 2019-07-19      246.00      290.0      244.00      264.00  2.031917e+08
# 2019-07-20      264.00      268.0      256.00      260.00  3.694070e+06
# 2019-07-21      260.00      263.0      250.00      252.00  1.606175e+06
# 2019-07-22      253.00      257.0      252.00      255.00  2.488802e+04
#
#             noise  noise_ma20 ticker          ma5  bull_ma         v_ma5  \
# 2017-01-02    NaN         NaN    BTC          NaN    False           NaN
# 2017-01-03   0.06         NaN    BTC          NaN    False           NaN
# 2017-01-04   0.87         NaN    BTC          NaN    False           NaN
# 2017-01-05   0.27         NaN    BTC          NaN    False           NaN
# 2017-01-06   0.85         NaN    BTC          NaN    False           NaN
# 2017-01-07   0.67         NaN    BTC  1313200.000    False  1.582919e+04
# 2017-01-08   0.76         NaN    BTC  1271600.000    False  1.754335e+04
# 2017-01-09   0.55         NaN    BTC  1236400.000    False  1.705118e+04
# 2017-01-10   0.44         NaN    BTC  1179600.000    False  1.709440e+04
# 2017-01-11   0.80         NaN    BTC  1137400.000    False  1.370972e+04
# 2017-01-12   0.47         NaN    BTC  1102400.000    False  1.203020e+04
# 2017-01-13   0.34         NaN    BTC  1064200.000    False  1.111714e+04
# 2017-01-14   0.53         NaN    BTC  1023400.000    False  1.120238e+04
# 2017-01-15   0.43         NaN    BTC   997000.000    False  1.065624e+04
# 2017-01-16   0.59         NaN    BTC   969400.000     True  1.028315e+04
# 2017-01-17   0.58         NaN    BTC   967000.000     True  8.696533e+03
# 2017-01-18   0.41         NaN    BTC   995200.000     True  8.299682e+03
# 2017-01-19   0.75         NaN    BTC  1010000.000     True  8.248110e+03
# 2017-01-20   0.40         NaN    BTC  1025400.000     True  8.115469e+03
# 2017-01-21   0.76         NaN    BTC  1044400.000     True  8.087393e+03
# 2017-01-22   0.29      0.5410    BTC  1066800.000     True  8.166619e+03
# 2017-01-23   0.98      0.5870    BTC  1072600.000     True  6.984510e+03
# 2017-01-24   0.54      0.5705    BTC  1085400.000     True  5.430639e+03
# 2017-01-25   0.38      0.5760    BTC  1089400.000    False  5.147284e+03
# 2017-01-26   0.57      0.5620    BTC  1090800.000    False  5.115433e+03
# 2017-01-27   0.29      0.5430    BTC  1089200.000     True  4.794209e+03
# 2017-01-28   0.86      0.5480    BTC  1088800.000     True  4.156205e+03
# 2017-01-29   0.62      0.5515    BTC  1087800.000     True  3.528911e+03
# 2017-01-30   0.20      0.5395    BTC  1090800.000     True  2.668156e+03
# 2017-01-31   1.00      0.5495    BTC  1095400.000     True  2.096359e+03
# ...           ...         ...    ...          ...      ...           ...
# 2019-07-18   0.42         NaN    HYC       10.162    False  1.611702e+08
# 2019-07-19   0.36         NaN    HYC        9.640    False  1.017215e+08
# 2019-07-20   0.52         NaN    HYC        9.500     True  9.767436e+07
# 2019-07-21   0.69         NaN    HYC        9.500     True  8.887900e+07
# 2019-07-22   0.31         NaN    HYC        9.406    False  1.120032e+08
# 2019-07-04    NaN         NaN    LBA          NaN    False           NaN
# 2019-07-05   0.83         NaN    LBA          NaN    False           NaN
# 2019-07-06   0.42         NaN    LBA          NaN    False           NaN
# 2019-07-07   0.26         NaN    LBA          NaN    False           NaN
# 2019-07-08   0.92         NaN    LBA          NaN    False           NaN
# 2019-07-09   0.33         NaN    LBA       51.740    False  5.716071e+08
# 2019-07-10   0.49         NaN    LBA       49.560    False  3.891258e+08
# 2019-07-11   0.87         NaN    LBA       47.920    False  2.062569e+08
# 2019-07-12   0.56         NaN    LBA       46.080    False  1.747100e+07
# 2019-07-13   1.00         NaN    LBA       44.180    False  1.509523e+07
# 2019-07-14   0.83         NaN    LBA       42.540    False  1.558781e+07
# 2019-07-15   0.22         NaN    LBA       40.380    False  1.523388e+07
# 2019-07-16   0.45         NaN    LBA       37.780    False  1.029914e+07
# 2019-07-17   0.24         NaN    LBA       35.360    False  9.824991e+06
# 2019-07-18   0.38         NaN    LBA       32.060    False  1.372025e+07
# 2019-07-19   0.93         NaN    LBA       28.960    False  1.532280e+07
# 2019-07-20   0.53         NaN    LBA       27.020    False  1.706932e+07
# 2019-07-21   0.23         NaN    LBA       26.180     True  1.700345e+07
# 2019-07-22   0.57         NaN    LBA       25.680     True  1.605645e+07
# 2019-07-17    NaN         NaN   LAMB          NaN    False           NaN
# 2019-07-18   0.59         NaN   LAMB          NaN    False           NaN
# 2019-07-19   0.87         NaN   LAMB          NaN    False           NaN
# 2019-07-20   0.61         NaN   LAMB          NaN    False           NaN
# 2019-07-21   0.67         NaN   LAMB          NaN    False           NaN
# 2019-07-22   0.38         NaN   LAMB      253.000    False  1.159125e+08
#
#             bull_vma
# 2017-01-02     False
# 2017-01-03     False
# 2017-01-04     False
# 2017-01-05     False
# 2017-01-06     False
# 2017-01-07      True
# 2017-01-08     False
# 2017-01-09     False
# 2017-01-10     False
# 2017-01-11     False
# 2017-01-12      True
# 2017-01-13      True
# 2017-01-14     False
# 2017-01-15     False
# 2017-01-16     False
# 2017-01-17      True
# 2017-01-18      True
# 2017-01-19     False
# 2017-01-20     False
# 2017-01-21     False
# 2017-01-22     False
# 2017-01-23     False
# 2017-01-24     False
# 2017-01-25     False
# 2017-01-26     False
# 2017-01-27     False
# 2017-01-28     False
# 2017-01-29     False
# 2017-01-30     False
# 2017-01-31      True
# ...              ...
# 2019-07-18     False
# 2019-07-19      True
# 2019-07-20     False
# 2019-07-21      True
# 2019-07-22     False
# 2019-07-04     False
# 2019-07-05     False
# 2019-07-06     False
# 2019-07-07     False
# 2019-07-08     False
# 2019-07-09     False
# 2019-07-10     False
# 2019-07-11     False
# 2019-07-12     False
# 2019-07-13     False
# 2019-07-14     False
# 2019-07-15     False
# 2019-07-16     False
# 2019-07-17      True
# 2019-07-18      True
# 2019-07-19      True
# 2019-07-20     False
# 2019-07-21     False
# 2019-07-22     False
# 2019-07-17     False
# 2019-07-18     False
# 2019-07-19     False
# 2019-07-20     False
# 2019-07-21     False
# 2019-07-22     False
#
# [31316 rows x 12 columns]

# %%
def aaa(date):
    df = noise_df[date].sort_values(by='noise').head(3)
    fee = 0.0032
# ror
    df['ror'] = np.where(df['bull_ma'] & df['bull_vma'],
                         df['close']/df['open']-fee,
                         1)
    return df

# %%
date = pd.date_range(start='2017-01-01', end='2017-7-21')
date
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#                '2017-01-05', '2017-01-06', '2017-01-07', '2017-01-08',
#                '2017-01-09', '2017-01-10',
#                ...
#                '2017-07-12', '2017-07-13', '2017-07-14', '2017-07-15',
#                '2017-07-16', '2017-07-17', '2017-07-18', '2017-07-19',
#                '2017-07-20', '2017-07-21'],
#               dtype='datetime64[ns]', length=202, freq='D')

# %%
aa = date.strftime('%Y-%m-%d')

# %%
result_df = pd.DataFrame()
for i in aa:
    df = aaa(i)
    result_df = result_df.append(df)

# %%
result_df.head()
result_df['hpr'] = result_df['ror'].cumprod()
result_df['ror'].min()
# Out:
# 0.7453294117647059
